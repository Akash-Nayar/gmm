# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
import math
# np.set_printoptions(threshold=np.inf)

# %%
class GMM():
    def __init__(self):
        self.n_clusters = 0
        self.pi = None
        self.mu = None
        self.sigma = None
        
    
    def calculate_weights(self, X, pi, mu, sigma):
        assert(len(pi) == len(mu) == len(sigma))
        w = np.ones((self.n_clusters, len(X)), dtype=np.float64)
        constant = np.sqrt(np.linalg.det(np.linalg.inv(sigma))[:, np.newaxis])
        for i in range(len(X)):
            for j in range(len(mu)):
                w[j][i] *= math.exp(-0.05 * (X[i] - mu[j])[None,:] @ np.linalg.inv(sigma[j]) @ (X[i] - mu[j])[:, None])
        w *= constant * pi
        return w / np.sum(w, axis=0)[None, :]
    
    
    def predict(self, X):
        assert(not (self.pi is None or self.mu is None or self.sigma is None))
        return np.argmax(self.calculate_weights(X, self.pi, self.mu, self.sigma), axis=0)     
        
    
    def fit(self, X, n_clusters, max_retries=10, epsilon=0.001):
        assert(n_clusters > 0)
        self.n_clusters = n_clusters
        b_clusters, b_loss = [], float("inf")
        for f in range(max_retries):
            pi = np.ones((n_clusters, 1)) / n_clusters
            mu = (np.random.rand(n_clusters, X.shape[1]) * (np.amax(X, axis=0) - np.amin(X, axis=0)) + np.amin(X, axis=0))
            sigma = np.array([np.eye(X.shape[1]) for _ in range(n_clusters)])
            for fg in range(50): # replace with termination when loss < epsilon
                w = self.calculate_weights(X, pi, mu, sigma)
                n = np.sum(w, axis=1)[:,None]
                pi = n / np.sum(n)
                mu = (w @ X) / n
                for j in range(n_clusters):
                    sigma[j] = np.dot(np.array([(X[i] - mu[j]) @ (X[i] - mu[j]).T for i in range(len(X))]), w[j][:, None])
                sigma /= n[:, :, None]
                sigma += 0.00000001 * np.eye(data.shape[1])
            self.pi = pi
            self.mu = mu
            self.sigma = sigma

# %%
np.random.seed(42)

# %%
cluster1 = np.random.normal(size=(200, 2)) * 0.0003 - np.array([0.004, -0.0005])
cluster2 = np.random.normal(size=(100, 2)) * 0.0005 - np.array([-0.0005, -0.0005])
cluster3 = np.random.normal(size=(50, 2)) * 0.0002 - np.array([0, 0.005])
data = np.vstack((cluster1, cluster2, cluster3))

# %%
plt.scatter(*(data.T))

# %%
gmm = GMM()
gmm.fit(data, 3, max_retries=1)

# %%
print(gmm.sigma)
print(gmm.pi)
print(gmm.mu)
# Out:
# [[[9.97474339e-08 8.97474339e-08]
#   [8.97474339e-08 9.97474339e-08]]
#
#  [[1.75531019e-07 1.65531019e-07]
#   [1.65531019e-07 1.75531019e-07]]
#
#  [[5.00764528e-07 4.90764528e-07]
#   [4.90764528e-07 5.00764528e-07]]]
# [[0.14285714]
#  [0.57142857]
#  [0.28571429]]
# [[-1.03253139e-05 -4.98003714e-03]
#  [-3.99809733e-03  5.11626496e-04]
#  [ 4.77481307e-04  4.36863659e-04]]

# %%
color_map = ['red', 'green', 'blue']
colors = []
for pred in gmm.predict(data):
    colors.append(color_map[pred])

# %%
plt.scatter(*(data.T), color=colors)
for i in range(3):
    plt.scatter(gmm.mu[:, 0], gmm.mu[:, 1], color=color_map, marker='x')

# %%
# original implementation: 1.35 s ± 42.8 ms

# %%
# vectorize constant calculation: 747 ms ± 5.11 ms

# %%
# %%timeit
gmm.fit(data, 3, max_retries=1)
# Out:
# 730 ms ± 19.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
